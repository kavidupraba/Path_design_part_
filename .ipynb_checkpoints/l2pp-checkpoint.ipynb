# %%
""" Functions for generating 2D grid maps, for AI Lab 2 - path planning.
"""

import random
import numpy as np
import matplotlib.pyplot as plt

percentOfObstacle = 0.9  # 30% - 60%, random

def generateMap2d(size_):

    '''Generates a random 2d map with obstacles (small blocks) randomly distributed. 
       You can specify any size of this map but your solution has to be independent of map size

    Parameters:
    -----------
    size_ : list
        Width and height of the 2d grid map, e.g. [60, 60]. The height and width of the map shall be greater than 20.

    Returns:
    --------
        map2d : array-like, shape (size_[0], size_[1])
           A 2d grid map, cells with a value of 0: Free cell; 
                                                -1: Obstacle;
                                                -2: Start point;
                                                -3: Goal point;
    '''
    
    size_x, size_y = size_[0], size_[1]

    map2d = np.random.rand(size_y, size_x)
    perObstacles_ = percentOfObstacle
    map2d[map2d <= perObstacles_] = 0
    map2d[map2d > perObstacles_] = -1

    yloc, xloc = [np.random.randint(0, size_x-1, 2), np.random.randint(0, size_y-1, 2)]
    while (yloc[0] == yloc[1]) and (xloc[0] == xloc[1]):
        yloc, xloc = [np.random.randint(0, size_x-1,2), np.random.randint(0, size_y-1, 2)]

    map2d[xloc[0]][yloc[0]] = -2
    map2d[xloc[1]][yloc[1]] = -3

    return map2d

# Generate 2d grid map with rotated-H-shape object
def generateMap2d_obstacle(size_):
    '''Generates a random 2d map with a rotated-H-shape object in the middle and obstacles (small blocks) randomly distributed. 
       You can specify any size of this map but your solution has to be independent of map size

    Parameters:
    -----------
    size_ : list
        Width and height of the 2d grid map, e.g. [60, 60]. The height and width of the map shall be greater than 40.

    Returns:
    --------
        map2d : array-like, shape (size_[0], size_[1])
           A 2d grid map, cells with a value of 0: Free cell; 
                                               -1: Obstacle;
                                               -2: Start point;
                                               -3: Goal point;
                                            
       [ytop, ybot, minx] : list
           information of the rotated-H-shape object
           ytop - y coordinate of the top horizontal wall/part
           ybot - y coordinate of the bottom horizontal wall/part
           minx - X coordinate of the vertical wall 
    '''
    
    size_x, size_y = size_[0], size_[1]
    map2d = generateMap2d(size_)

    map2d[map2d==-2] = 0
    map2d[map2d==-3] = 0

    # add special obstacle
    xtop = [np.random.randint(5, 3*size_x//10-2), np.random.randint(7*size_x//10+3, size_x-5)]
    ytop = np.random.randint(7*size_y//10 + 3, size_y - 5)
    xbot = np.random.randint(3, 3*size_x//10-5), np.random.randint(7*size_x//10+3, size_x-5)
    ybot = np.random.randint(5, size_y//5 - 3)


    map2d[ybot, xbot[0]:xbot[1]+1] = -1
    map2d[ytop, xtop[0]:xtop[1]+1] = -1
    minx = (xbot[0]+xbot[1])//2
    maxx = (xtop[0]+xtop[1])//2
    if minx > maxx:
        tempx = minx
        minx = maxx
        maxx = tempx
    if maxx == minx:
        maxx = maxx+1

    map2d[ybot:ytop, minx:maxx] = -1
    startp = [np.random.randint(0, size_x//2 - 4), np.random.randint(ybot+1, ytop-1)]

    map2d[startp[1], startp[0]] = -2
    goalp = [np.random.randint(size_x//2 + 4, size_x - 3), np.random.randint(ybot+1, ytop-1)]

    map2d[goalp[1],goalp[0]] = -3
    #return map2d, [startp[1], startp[0]], [goalp[1], goalp[0]], [ytop, ybot]
    return map2d, [ytop, ybot, minx]


# helper function for plotting the result
def plotMap(map2d_, path_, title_ =''):
    
    '''Plots a map (image) of a 2d matrix with a path from start point to the goal point. 
        cells with a value of 0: Free cell; 
                             -1: Obstacle;
                             -2: Start point;
                             -3: Goal point;
    Parameters:
    -----------
    map2d_ : array-like
        an array with Real Numbers
        
    path_ : array-like
        an array of 2d corrdinates (of the path) in the format of [[x0, y0], [x1, y1], [x2, y2], ..., [x_end, y_end]]
        
    title_ : string
        information/description of the plot

    Returns:
    --------

    '''
    
    import matplotlib.cm as cm
    plt.interactive(False)
    
    colors_nn = int(map2d_.max())
    colors = cm.winter(np.linspace(0, 1, colors_nn))

    colorsMap2d = [[[] for x in range(map2d_.shape[1])] for y in range(map2d_.shape[0])]
    # Assign RGB Val for starting point and ending point
    locStart, locEnd = np.where(map2d_ == -2), np.where(map2d_ == -3)
    
    colorsMap2d[locStart[0][0]][locStart[1][0]] = [.0, .0, .0, 1.0]  # black
    colorsMap2d[locEnd[0][0]][locEnd[1][0]] = [.0, .0, .0, .0]  # white

    # Assign RGB Val for obstacle
    locObstacle = np.where(map2d_ == -1)
    for iposObstacle in range(len(locObstacle[0])):
        colorsMap2d[locObstacle[0][iposObstacle]][locObstacle[1][iposObstacle]] = [1.0, .0, .0, 1.0]
    # Assign 0
    locZero = np.where(map2d_ == 0)

    for iposZero in range(len(locZero[0])):
        colorsMap2d[locZero[0][iposZero]][locZero[1][iposZero]] = [1.0, 1.0, 1.0, 1.0]

    # Assign Expanded nodes
    locExpand = np.where(map2d_>0)

    for iposExpand in range(len(locExpand[0])):
        _idx_ = int(map2d_[locExpand[0][iposExpand]][locExpand[1][iposExpand]]-1)
        colorsMap2d[locExpand[0][iposExpand]][locExpand[1][iposExpand]] = colors[_idx_]

    for irow in range(len(colorsMap2d)):
        for icol in range(len(colorsMap2d[irow])):
            if colorsMap2d[irow][icol] == []:
                colorsMap2d[irow][icol] = [1.0, 0.0, 0.0, 1.0]
                
    path = path_.T.tolist()
    
    plt.figure()
    plt.title(title_)
    plt.imshow(colorsMap2d, interpolation='nearest')
    plt.colorbar()
    plt.plot(path[:][0],path[:][1], color='magenta',linewidth=2.5)
    plt.show()



# create a map with obstacles randomly distributed
#  0 - Free cell
# -1 - Obstacle
# -2 - Start point
# -3 - Goal point
_map_ = generateMap2d([60, 60])
plt.clf()
plt.imshow(_map_)
plt.show()

# map with rotated-H shape obstacle and obstacles randomly distributed
map_h_object, info = generateMap2d_obstacle([60, 60])

# environment information
print("map info: ")
print("y top: ", info[0])
print("t bot: ", info[1])
print("x wall: ", info[2])

plt.clf()
plt.imshow(map_h_object)
plt.show()


# example for a solved_map
#  0 - unexpanded cell
# -1 - obstacle
# -2 - start point
# -3 - goal point
# positive_numbers - one type of the values described in lab2 description (heuristic cost, travel cost, cell total cost,...)

example_solved_map = map_h_object
example_solved_path = np.array([[xx, xx*2] if xx % 2 == 0 else [xx, xx+1] for xx in range(20)])

print("path", example_solved_path)

plotMap(example_solved_map, example_solved_path)
# Out:
# ------------ print game info ---------------
# nn_states_total 132
# 1
# ************* state info **************
# nn_current_hand 11
# nn_current_bidding 0
# phase SHOWDOWN
# pot 0
# acting_agent opponent
# parent_state <__main__.GameState object at 0x7faaea7c7940>
# children None
# agent <__main__.PokerPlayer object at 0x7faaea7c7a90>
# opponent <__main__.PokerPlayer object at 0x7faaea7c7340>
# ---------- showdown ----------
# agent.current_hand ['7c', '4c', 'Ts', 'Th', '5c']
# ['OnePair', 'T', 's'] 35
# opponent.current_hand ['7d', 'Qc', '8s', '5d', '9s']
# ['HighCard', 'Q', 'c'] 24
# showdown_info agent win
# ----- agent -----
# agent.current_hand ['7c', '4c', 'Ts', 'Th', '5c']
# agent.current_hand_type ['OnePair', 'T', 's']
# agent.current_hand_strength 35
# agent.stack 502.5
# agent.action BET10
# agent.action_value 10
# ----- opponent -----
# opponent.current_hand ['7d', 'Qc', '8s', '5d', '9s']
# opponent.current_hand_type ['HighCard', 'Q', 'c']
# opponent.current_hand_strength 24
# opponent.stack 297.5
# opponent.action CALL
# opponent.action_value 5
# **************** end ******************
# 2
# ************* state info **************
# nn_current_hand 10
# nn_current_bidding 3
# phase BIDDING
# pot 45
# acting_agent agent
# parent_state <__main__.GameState object at 0x7faaea7c70a0>
# children None
# agent <__main__.PokerPlayer object at 0x7faaea7c7400>
# opponent <__main__.PokerPlayer object at 0x7faaea7c7430>
# ----- agent -----
# agent.current_hand ['7c', '4c', 'Ts', 'Th', '5c']
# agent.current_hand_type ['OnePair', 'T', 's']
# agent.current_hand_strength 35
# agent.stack 452.5
# agent.action BET10
# agent.action_value 10
# ----- opponent -----
# opponent.current_hand ['7d', 'Qc', '8s', '5d', '9s']
# opponent.current_hand_type ['HighCard', 'Q', 'c']
# opponent.current_hand_strength 24
# opponent.stack 302.5
# opponent.action BET
# opponent.action_value 25
# **************** end ******************
# 3
# ************* state info **************
# nn_current_hand 10
# nn_current_bidding 2
# phase BIDDING
# pot 35
# acting_agent opponent
# parent_state <__main__.GameState object at 0x7faaea7c7790>
# children None
# agent <__main__.PokerPlayer object at 0x7faaea7c72b0>
# opponent <__main__.PokerPlayer object at 0x7faaea7c7b50>
# ----- agent -----
# agent.current_hand ['7c', '4c', 'Ts', 'Th', '5c']
# agent.current_hand_type ['OnePair', 'T', 's']
# agent.current_hand_strength 35
# agent.stack 462.5
# agent.action BET10
# agent.action_value 10
# ----- opponent -----
# opponent.current_hand ['7d', 'Qc', '8s', '5d', '9s']
# opponent.current_hand_type ['HighCard', 'Q', 'c']
# opponent.current_hand_strength 24
# opponent.stack 302.5
# opponent.action BET
# opponent.action_value 25
# **************** end ******************
# 4
# ************* state info **************
# nn_current_hand 10
# nn_current_bidding 1
# phase BIDDING
# pot 10
# acting_agent agent
# parent_state <__main__.GameState object at 0x7faaea7c7850>
# children None
# agent <__main__.PokerPlayer object at 0x7faaea7c7730>
# opponent <__main__.PokerPlayer object at 0x7faaea7c7fd0>
# ----- agent -----
# agent.current_hand ['7c', '4c', 'Ts', 'Th', '5c']
# agent.current_hand_type ['OnePair', 'T', 's']
# agent.current_hand_strength 35
# agent.stack 462.5
# agent.action BET10
# agent.action_value 10
# ----- opponent -----
# opponent.current_hand ['7d', 'Qc', '8s', '5d', '9s']
# opponent.current_hand_type ['HighCard', 'Q', 'c']
# opponent.current_hand_strength 24
# opponent.stack 327.5
# opponent.action CALL
# opponent.action_value 5
# **************** end ******************
# 5
# ************* state info **************
# nn_current_hand 10
# nn_current_bidding 0
# phase SHOWDOWN
# pot 0
# acting_agent opponent
# parent_state <__main__.GameState object at 0x7faaea7c7eb0>
# children None
# agent <__main__.PokerPlayer object at 0x7faaea7c7190>
# opponent <__main__.PokerPlayer object at 0x7faaea7c75e0>
# ---------- showdown ----------
# agent.current_hand ['2c', '5c', 'As', '7s', 'Ac']
# ['OnePair', 'A', 's'] 39
# opponent.current_hand ['Ah', 'Tc', 'Jc', '2h', '9c']
# ['HighCard', 'A', 'h'] 26
# showdown_info agent win
# ----- agent -----
# agent.current_hand ['2c', '5c', 'As', '7s', 'Ac']
# agent.current_hand_type ['OnePair', 'A', 's']
# agent.current_hand_strength 39
# agent.stack 472.5
# agent.action BET10
# agent.action_value 10
# ----- opponent -----
# opponent.current_hand ['Ah', 'Tc', 'Jc', '2h', '9c']
# opponent.current_hand_type ['HighCard', 'A', 'h']
# opponent.current_hand_strength 26
# opponent.stack 327.5
# opponent.action CALL
# opponent.action_value 5
# **************** end ******************
# 6
# ************* state info **************
# nn_current_hand 9
# nn_current_bidding 3
# phase BIDDING
# pot 45
# acting_agent agent
# parent_state <__main__.GameState object at 0x7faaea72c910>
# children None
# agent <__main__.PokerPlayer object at 0x7faaea7c7370>
# opponent <__main__.PokerPlayer object at 0x7faaea7c73a0>
# ----- agent -----
# agent.current_hand ['2c', '5c', 'As', '7s', 'Ac']
# agent.current_hand_type ['OnePair', 'A', 's']
# agent.current_hand_strength 39
# agent.stack 422.5
# agent.action BET10
# agent.action_value 10
# ----- opponent -----
# opponent.current_hand ['Ah', 'Tc', 'Jc', '2h', '9c']
# opponent.current_hand_type ['HighCard', 'A', 'h']
# opponent.current_hand_strength 26
# opponent.stack 332.5
# opponent.action BET
# opponent.action_value 25
# **************** end ******************
# 7
# ************* state info **************
# nn_current_hand 9
# nn_current_bidding 2
# phase BIDDING
# pot 35
# acting_agent opponent
# parent_state <__main__.GameState object at 0x7faaea72cbe0>
# children None
# agent <__main__.PokerPlayer object at 0x7faaea72ca60>
# opponent <__main__.PokerPlayer object at 0x7faaea72c6a0>
# ----- agent -----
# agent.current_hand ['2c', '5c', 'As', '7s', 'Ac']
# agent.current_hand_type ['OnePair', 'A', 's']
# agent.current_hand_strength 39
# agent.stack 432.5
# agent.action BET10
# agent.action_value 10
# ----- opponent -----
# opponent.current_hand ['Ah', 'Tc', 'Jc', '2h', '9c']
# opponent.current_hand_type ['HighCard', 'A', 'h']
# opponent.current_hand_strength 26
# opponent.stack 332.5
# opponent.action BET
# opponent.action_value 25
# **************** end ******************
# 8
# ************* state info **************
# nn_current_hand 9
# nn_current_bidding 1
# phase BIDDING
# pot 10
# acting_agent agent
# parent_state <__main__.GameState object at 0x7faaea72c760>
# children None
# agent <__main__.PokerPlayer object at 0x7faaea72c7c0>
# opponent <__main__.PokerPlayer object at 0x7faaea72c7f0>
# ----- agent -----
# agent.current_hand ['2c', '5c', 'As', '7s', 'Ac']
# agent.current_hand_type ['OnePair', 'A', 's']
# agent.current_hand_strength 39
# agent.stack 432.5
# agent.action BET10
# agent.action_value 10
# ----- opponent -----
# opponent.current_hand ['Ah', 'Tc', 'Jc', '2h', '9c']
# opponent.current_hand_type ['HighCard', 'A', 'h']
# opponent.current_hand_strength 26
# opponent.stack 357.5
# opponent.action CALL
# opponent.action_value 5
# **************** end ******************
# 9
# ************* state info **************
# nn_current_hand 9
# nn_current_bidding 0
# phase SHOWDOWN
# pot 0
# acting_agent opponent
# parent_state <__main__.GameState object at 0x7faaea72cbb0>
# children None
# agent <__main__.PokerPlayer object at 0x7faaea72cd30>
# opponent <__main__.PokerPlayer object at 0x7faaea72c640>
# ---------- showdown ----------
# agent.current_hand ['2d', 'Ad', 'Tc', '7s', 'Jd']
# ['HighCard', 'A', 'd'] 26
# opponent.current_hand ['3d', '5c', 'Ac', 'Td', '9d']
# ['HighCard', 'A', 'c'] 26
# showdown_info draw
# ----- agent -----
# agent.current_hand ['2d', 'Ad', 'Tc', '7s', 'Jd']
# agent.current_hand_type ['HighCard', 'A', 'd']
# agent.current_hand_strength 26
# agent.stack 442.5
# agent.action BET10
# agent.action_value 10
# ----- opponent -----
# opponent.current_hand ['3d', '5c', 'Ac', 'Td', '9d']
# opponent.current_hand_type ['HighCard', 'A', 'c']
# opponent.current_hand_strength 26
# opponent.stack 357.5
# opponent.action CALL
# opponent.action_value 5
# **************** end ******************
# 10
# ************* state info **************
# nn_current_hand 8
# nn_current_bidding 3
# phase BIDDING
# pot 45
# acting_agent agent
# parent_state <__main__.GameState object at 0x7faaea6bc400>
# children None
# agent <__main__.PokerPlayer object at 0x7faaea72c820>
# opponent <__main__.PokerPlayer object at 0x7faaea72c4c0>
# ----- agent -----
# agent.current_hand ['2d', 'Ad', 'Tc', '7s', 'Jd']
# agent.current_hand_type ['HighCard', 'A', 'd']
# agent.current_hand_strength 26
# agent.stack 420
# agent.action BET10
# agent.action_value 10
# ----- opponent -----
# opponent.current_hand ['3d', '5c', 'Ac', 'Td', '9d']
# opponent.current_hand_type ['HighCard', 'A', 'c']
# opponent.current_hand_strength 26
# opponent.stack 335
# opponent.action BET
# opponent.action_value 25
# **************** end ******************
# 11
# ************* state info **************
# nn_current_hand 8
# nn_current_bidding 2
# phase BIDDING
# pot 35
# acting_agent opponent
# parent_state <__main__.GameState object at 0x7faaea6bc160>
# children None
# agent <__main__.PokerPlayer object at 0x7faaea72cd90>
# opponent <__main__.PokerPlayer object at 0x7faaea72cc70>
# ----- agent -----
# agent.current_hand ['2d', 'Ad', 'Tc', '7s', 'Jd']
# agent.current_hand_type ['HighCard', 'A', 'd']
# agent.current_hand_strength 26
# agent.stack 430
# agent.action BET10
# agent.action_value 10
# ----- opponent -----
# opponent.current_hand ['3d', '5c', 'Ac', 'Td', '9d']
# opponent.current_hand_type ['HighCard', 'A', 'c']
# opponent.current_hand_strength 26
# opponent.stack 335
# opponent.action BET
# opponent.action_value 25
# **************** end ******************
# 12
# ************* state info **************
# nn_current_hand 8
# nn_current_bidding 1
# phase BIDDING
# pot 10
# acting_agent agent
# parent_state <__main__.GameState object at 0x7faaea6bca60>
# children None
# agent <__main__.PokerPlayer object at 0x7faaea6bc070>
# opponent <__main__.PokerPlayer object at 0x7faaea6bcc40>
# ----- agent -----
# agent.current_hand ['2d', 'Ad', 'Tc', '7s', 'Jd']
# agent.current_hand_type ['HighCard', 'A', 'd']
# agent.current_hand_strength 26
# agent.stack 430
# agent.action BET10
# agent.action_value 10
# ----- opponent -----
# opponent.current_hand ['3d', '5c', 'Ac', 'Td', '9d']
# opponent.current_hand_type ['HighCard', 'A', 'c']
# opponent.current_hand_strength 26
# opponent.stack 360
# opponent.action CALL
# opponent.action_value 5
# **************** end ******************
# 13
# ************* state info **************
# nn_current_hand 8
# nn_current_bidding 0
# phase SHOWDOWN
# pot 0
# acting_agent opponent
# parent_state <__main__.GameState object at 0x7faaea6bc970>
# children None
# agent <__main__.PokerPlayer object at 0x7faaea6bcd00>
# opponent <__main__.PokerPlayer object at 0x7faaea6bc370>
# ---------- showdown ----------
# agent.current_hand ['Kc', '3s', 'Ts', 'Qh', '8c']
# ['HighCard', 'K', 'c'] 25
# opponent.current_hand ['As', 'Kd', '9d', '7c', '2d']
# ['HighCard', 'A', 's'] 26
# showdown_info opponent win
# ----- agent -----
# agent.current_hand ['Kc', '3s', 'Ts', 'Qh', '8c']
# agent.current_hand_type ['HighCard', 'K', 'c']
# agent.current_hand_strength 25
# agent.stack 440
# agent.action BET10
# agent.action_value 10
# ----- opponent -----
# opponent.current_hand ['As', 'Kd', '9d', '7c', '2d']
# opponent.current_hand_type ['HighCard', 'A', 's']
# opponent.current_hand_strength 26
# opponent.stack 360
# opponent.action CALL
# opponent.action_value 5
# **************** end ******************
# 14
# ************* state info **************
# nn_current_hand 7
# nn_current_bidding 3
# phase BIDDING
# pot 45
# acting_agent agent
# parent_state <__main__.GameState object at 0x7faaea6bc4f0>
# children None
# agent <__main__.PokerPlayer object at 0x7faaea6bce20>
# opponent <__main__.PokerPlayer object at 0x7faaea6bcaf0>
# ----- agent -----
# agent.current_hand ['Kc', '3s', 'Ts', 'Qh', '8c']
# agent.current_hand_type ['HighCard', 'K', 'c']
# agent.current_hand_strength 25
# agent.stack 440
# agent.action BET10
# agent.action_value 10
# ----- opponent -----
# opponent.current_hand ['As', 'Kd', '9d', '7c', '2d']
# opponent.current_hand_type ['HighCard', 'A', 's']
# opponent.current_hand_strength 26
# opponent.stack 315
# opponent.action BET
# opponent.action_value 25
# **************** end ******************
# 15
# ************* state info **************
# nn_current_hand 7
# nn_current_bidding 2
# phase BIDDING
# pot 35
# acting_agent opponent
# parent_state <__main__.GameState object at 0x7faaea6bc550>
# children None
# agent <__main__.PokerPlayer object at 0x7faaea6bcf10>
# opponent <__main__.PokerPlayer object at 0x7faaea6bc5e0>
# ----- agent -----
# agent.current_hand ['Kc', '3s', 'Ts', 'Qh', '8c']
# agent.current_hand_type ['HighCard', 'K', 'c']
# agent.current_hand_strength 25
# agent.stack 450
# agent.action BET10
# agent.action_value 10
# ----- opponent -----
# opponent.current_hand ['As', 'Kd', '9d', '7c', '2d']
# opponent.current_hand_type ['HighCard', 'A', 's']
# opponent.current_hand_strength 26
# opponent.stack 315
# opponent.action BET
# opponent.action_value 25
# **************** end ******************
# 16
# ************* state info **************
# nn_current_hand 7
# nn_current_bidding 1
# phase BIDDING
# pot 10
# acting_agent agent
# parent_state <__main__.GameState object at 0x7faaea6bce80>
# children None
# agent <__main__.PokerPlayer object at 0x7faaea6bc040>
# opponent <__main__.PokerPlayer object at 0x7faaea6bc340>
# ----- agent -----
# agent.current_hand ['Kc', '3s', 'Ts', 'Qh', '8c']
# agent.current_hand_type ['HighCard', 'K', 'c']
# agent.current_hand_strength 25
# agent.stack 450
# agent.action BET10
# agent.action_value 10
# ----- opponent -----
# opponent.current_hand ['As', 'Kd', '9d', '7c', '2d']
# opponent.current_hand_type ['HighCard', 'A', 's']
# opponent.current_hand_strength 26
# opponent.stack 340
# opponent.action CALL
# opponent.action_value 5
# **************** end ******************
# 17
# ************* state info **************
# nn_current_hand 7
# nn_current_bidding 0
# phase SHOWDOWN
# pot 0
# acting_agent opponent
# parent_state <__main__.GameState object at 0x7faaea6bceb0>
# children None
# agent <__main__.PokerPlayer object at 0x7faaea6bccd0>
# opponent <__main__.PokerPlayer object at 0x7faaea6bcd60>
# ---------- showdown ----------
# agent.current_hand ['5s', '5d', '8c', 'Tc', '7h']
# ['OnePair', '5', 's'] 30
# opponent.current_hand ['Jd', '5h', 'Kd', 'Ad', '8s']
# ['HighCard', 'A', 'd'] 26
# showdown_info agent win
# ----- agent -----
# agent.current_hand ['5s', '5d', '8c', 'Tc', '7h']
# agent.current_hand_type ['OnePair', '5', 's']
# agent.current_hand_strength 30
# agent.stack 460
# agent.action BET10
# agent.action_value 10
# ----- opponent -----
# opponent.current_hand ['Jd', '5h', 'Kd', 'Ad', '8s']
# opponent.current_hand_type ['HighCard', 'A', 'd']
# opponent.current_hand_strength 26
# opponent.stack 340
# opponent.action CALL
# opponent.action_value 5
# **************** end ******************
# 18
# ************* state info **************
# nn_current_hand 6
# nn_current_bidding 3
# phase BIDDING
# pot 45
# acting_agent agent
# parent_state <__main__.GameState object at 0x7faaea6bc9d0>
# children None
# agent <__main__.PokerPlayer object at 0x7faaea6bcd90>
# opponent <__main__.PokerPlayer object at 0x7faaea6bc520>
# ----- agent -----
# agent.current_hand ['5s', '5d', '8c', 'Tc', '7h']
# agent.current_hand_type ['OnePair', '5', 's']
# agent.current_hand_strength 30
# agent.stack 410
# agent.action BET10
# agent.action_value 10
# ----- opponent -----
# opponent.current_hand ['Jd', '5h', 'Kd', 'Ad', '8s']
# opponent.current_hand_type ['HighCard', 'A', 'd']
# opponent.current_hand_strength 26
# opponent.stack 345
# opponent.action BET
# opponent.action_value 25
# **************** end ******************
# 19
# ************* state info **************
# nn_current_hand 6
# nn_current_bidding 2
# phase BIDDING
# pot 35
# acting_agent opponent
# parent_state <__main__.GameState object at 0x7faaea6bc850>
# children None
# agent <__main__.PokerPlayer object at 0x7faaea6bc0a0>
# opponent <__main__.PokerPlayer object at 0x7faaea6bc130>
# ----- agent -----
# agent.current_hand ['5s', '5d', '8c', 'Tc', '7h']
# agent.current_hand_type ['OnePair', '5', 's']
# agent.current_hand_strength 30
# agent.stack 420
# agent.action BET10
# agent.action_value 10
# ----- opponent -----
# opponent.current_hand ['Jd', '5h', 'Kd', 'Ad', '8s']
# opponent.current_hand_type ['HighCard', 'A', 'd']
# opponent.current_hand_strength 26
# opponent.stack 345
# opponent.action BET
# opponent.action_value 25
# **************** end ******************
# 20
# ************* state info **************
# nn_current_hand 6
# nn_current_bidding 1
# phase BIDDING
# pot 10
# acting_agent agent
# parent_state <__main__.GameState object at 0x7faaeab37b80>
# children None
# agent <__main__.PokerPlayer object at 0x7faaea6bc790>
# opponent <__main__.PokerPlayer object at 0x7faaea6bc730>
# ----- agent -----
# agent.current_hand ['5s', '5d', '8c', 'Tc', '7h']
# agent.current_hand_type ['OnePair', '5', 's']
# agent.current_hand_strength 30
# agent.stack 420
# agent.action BET10
# agent.action_value 10
# ----- opponent -----
# opponent.current_hand ['Jd', '5h', 'Kd', 'Ad', '8s']
# opponent.current_hand_type ['HighCard', 'A', 'd']
# opponent.current_hand_strength 26
# opponent.stack 370
# opponent.action CALL
# opponent.action_value 5
# **************** end ******************
# 21
# ************* state info **************
# nn_current_hand 6
# nn_current_bidding 0
# phase SHOWDOWN
# pot 0
# acting_agent opponent
# parent_state <__main__.GameState object at 0x7faaeab37bb0>
# children None
# agent <__main__.PokerPlayer object at 0x7faaeab37c10>
# opponent <__main__.PokerPlayer object at 0x7faaeab37cd0>
# ---------- showdown ----------
# agent.current_hand ['Kd', '4c', '6h', '4h', '2c']
# ['OnePair', '4', 'h'] 29
# opponent.current_hand ['Kc', 'Jc', '2s', '5d', '3s']
# ['HighCard', 'K', 'c'] 25
# showdown_info agent win
# ----- agent -----
# agent.current_hand ['Kd', '4c', '6h', '4h', '2c']
# agent.current_hand_type ['OnePair', '4', 'h']
# agent.current_hand_strength 29
# agent.stack 430
# agent.action BET10
# agent.action_value 10
# ----- opponent -----
# opponent.current_hand ['Kc', 'Jc', '2s', '5d', '3s']
# opponent.current_hand_type ['HighCard', 'K', 'c']
# opponent.current_hand_strength 25
# opponent.stack 370
# opponent.action CALL
# opponent.action_value 5
# **************** end ******************
# 22
# ************* state info **************
# nn_current_hand 5
# nn_current_bidding 3
# phase BIDDING
# pot 45
# acting_agent agent
# parent_state <__main__.GameState object at 0x7faaeab37f10>
# children None
# agent <__main__.PokerPlayer object at 0x7faaeab37a60>
# opponent <__main__.PokerPlayer object at 0x7faaeab37be0>
# ----- agent -----
# agent.current_hand ['Kd', '4c', '6h', '4h', '2c']
# agent.current_hand_type ['OnePair', '4', 'h']
# agent.current_hand_strength 29
# agent.stack 380
# agent.action BET10
# agent.action_value 10
# ----- opponent -----
# opponent.current_hand ['Kc', 'Jc', '2s', '5d', '3s']
# opponent.current_hand_type ['HighCard', 'K', 'c']
# opponent.current_hand_strength 25
# opponent.stack 375
# opponent.action BET
# opponent.action_value 25
# **************** end ******************
# 23
# ************* state info **************
# nn_current_hand 5
# nn_current_bidding 2
# phase BIDDING
# pot 35
# acting_agent opponent
# parent_state <__main__.GameState object at 0x7faaeab37f40>
# children None
# agent <__main__.PokerPlayer object at 0x7faaeab37a30>
# opponent <__main__.PokerPlayer object at 0x7faaeab37040>
# ----- agent -----
# agent.current_hand ['Kd', '4c', '6h', '4h', '2c']
# agent.current_hand_type ['OnePair', '4', 'h']
# agent.current_hand_strength 29
# agent.stack 390
# agent.action BET10
# agent.action_value 10
# ----- opponent -----
# opponent.current_hand ['Kc', 'Jc', '2s', '5d', '3s']
# opponent.current_hand_type ['HighCard', 'K', 'c']
# opponent.current_hand_strength 25
# opponent.stack 375
# opponent.action BET
# opponent.action_value 25
# **************** end ******************
# 24
# ************* state info **************
# nn_current_hand 5
# nn_current_bidding 1
# phase BIDDING
# pot 10
# acting_agent agent
# parent_state <__main__.GameState object at 0x7faaeab37f70>
# children None
# agent <__main__.PokerPlayer object at 0x7faaeab379d0>
# opponent <__main__.PokerPlayer object at 0x7faaeab37a00>
# ----- agent -----
# agent.current_hand ['Kd', '4c', '6h', '4h', '2c']
# agent.current_hand_type ['OnePair', '4', 'h']
# agent.current_hand_strength 29
# agent.stack 390
# agent.action BET10
# agent.action_value 10
# ----- opponent -----
# opponent.current_hand ['Kc', 'Jc', '2s', '5d', '3s']
# opponent.current_hand_type ['HighCard', 'K', 'c']
# opponent.current_hand_strength 25
# opponent.stack 400
# opponent.action CALL
# opponent.action_value 5
# **************** end ******************
# 25
# ************* state info **************
# nn_current_hand 5
# nn_current_bidding 0
# phase SHOWDOWN
# pot 0
# acting_agent opponent
# parent_state <__main__.GameState object at 0x7faaeab378e0>
# children None
# agent <__main__.PokerPlayer object at 0x7faaeab374f0>
# opponent <__main__.PokerPlayer object at 0x7faaeab37df0>
# ---------- showdown ----------
# agent.current_hand ['3s', '2c', '6s', '4s', '9s']
# ['HighCard', '9', 's'] 21
# opponent.current_hand ['Ks', '9c', '8c', 'Ts', '6d']
# ['HighCard', 'K', 's'] 25
# showdown_info opponent win
# ----- agent -----
# agent.current_hand ['3s', '2c', '6s', '4s', '9s']
# agent.current_hand_type ['HighCard', '9', 's']
# agent.current_hand_strength 21
# agent.stack 400
# agent.action BET10
# agent.action_value 10
# ----- opponent -----
# opponent.current_hand ['Ks', '9c', '8c', 'Ts', '6d']
# opponent.current_hand_type ['HighCard', 'K', 's']
# opponent.current_hand_strength 25
# opponent.stack 400
# opponent.action CALL
# opponent.action_value 5
# **************** end ******************
# 26
# ************* state info **************
# nn_current_hand 4
# nn_current_bidding 3
# phase BIDDING
# pot 45
# acting_agent agent
# parent_state <__main__.GameState object at 0x7faaeab37550>
# children None
# agent <__main__.PokerPlayer object at 0x7faaeab37fd0>
# opponent <__main__.PokerPlayer object at 0x7faaeab37fa0>
# ----- agent -----
# agent.current_hand ['3s', '2c', '6s', '4s', '9s']
# agent.current_hand_type ['HighCard', '9', 's']
# agent.current_hand_strength 21
# agent.stack 400
# agent.action BET10
# agent.action_value 10
# ----- opponent -----
# opponent.current_hand ['Ks', '9c', '8c', 'Ts', '6d']
# opponent.current_hand_type ['HighCard', 'K', 's']
# opponent.current_hand_strength 25
# opponent.stack 355
# opponent.action BET
# opponent.action_value 25
# **************** end ******************
# 27
# ************* state info **************
# nn_current_hand 4
# nn_current_bidding 2
# phase BIDDING
# pot 35
# acting_agent opponent
# parent_state <__main__.GameState object at 0x7faaeab372e0>
# children None
# agent <__main__.PokerPlayer object at 0x7faaeab373d0>
# opponent <__main__.PokerPlayer object at 0x7faaeab37490>
# ----- agent -----
# agent.current_hand ['3s', '2c', '6s', '4s', '9s']
# agent.current_hand_type ['HighCard', '9', 's']
# agent.current_hand_strength 21
# agent.stack 410
# agent.action BET10
# agent.action_value 10
# ----- opponent -----
# opponent.current_hand ['Ks', '9c', '8c', 'Ts', '6d']
# opponent.current_hand_type ['HighCard', 'K', 's']
# opponent.current_hand_strength 25
# opponent.stack 355
# opponent.action BET
# opponent.action_value 25
# **************** end ******************
# 28
# ************* state info **************
# nn_current_hand 4
# nn_current_bidding 1
# phase BIDDING
# pot 10
# acting_agent agent
# parent_state <__main__.GameState object at 0x7faaea8f9e80>
# children None
# agent <__main__.PokerPlayer object at 0x7faaeab37370>
# opponent <__main__.PokerPlayer object at 0x7faaeab37520>
# ----- agent -----
# agent.current_hand ['3s', '2c', '6s', '4s', '9s']
# agent.current_hand_type ['HighCard', '9', 's']
# agent.current_hand_strength 21
# agent.stack 410
# agent.action BET10
# agent.action_value 10
# ----- opponent -----
# opponent.current_hand ['Ks', '9c', '8c', 'Ts', '6d']
# opponent.current_hand_type ['HighCard', 'K', 's']
# opponent.current_hand_strength 25
# opponent.stack 380
# opponent.action CALL
# opponent.action_value 5
# **************** end ******************
# 29
# ************* state info **************
# nn_current_hand 4
# nn_current_bidding 0
# phase SHOWDOWN
# pot 0
# acting_agent opponent
# parent_state <__main__.GameState object at 0x7faaea8f9910>
# children None
# agent <__main__.PokerPlayer object at 0x7faaea8f9550>
# opponent <__main__.PokerPlayer object at 0x7faaeab376d0>
# ---------- showdown ----------
# agent.current_hand ['Kc', 'Ts', '4d', 'Jh', 'Jc']
# ['OnePair', 'J', 'h'] 36
# opponent.current_hand ['5s', '9c', 'Qh', '8h', '3s']
# ['HighCard', 'Q', 'h'] 24
# showdown_info agent win
# ----- agent -----
# agent.current_hand ['Kc', 'Ts', '4d', 'Jh', 'Jc']
# agent.current_hand_type ['OnePair', 'J', 'h']
# agent.current_hand_strength 36
# agent.stack 420
# agent.action BET10
# agent.action_value 10
# ----- opponent -----
# opponent.current_hand ['5s', '9c', 'Qh', '8h', '3s']
# opponent.current_hand_type ['HighCard', 'Q', 'h']
# opponent.current_hand_strength 24
# opponent.stack 380
# opponent.action CALL
# opponent.action_value 5
# **************** end ******************
# 30
# ************* state info **************
# nn_current_hand 3
# nn_current_bidding 3
# phase BIDDING
# pot 45
# acting_agent agent
# parent_state <__main__.GameState object at 0x7faaea8f9790>
# children None
# agent <__main__.PokerPlayer object at 0x7faaea8f9a00>
# opponent <__main__.PokerPlayer object at 0x7faaea8f9eb0>
# ----- agent -----
# agent.current_hand ['Kc', 'Ts', '4d', 'Jh', 'Jc']
# agent.current_hand_type ['OnePair', 'J', 'h']
# agent.current_hand_strength 36
# agent.stack 370
# agent.action BET10
# agent.action_value 10
# ----- opponent -----
# opponent.current_hand ['5s', '9c', 'Qh', '8h', '3s']
# opponent.current_hand_type ['HighCard', 'Q', 'h']
# opponent.current_hand_strength 24
# opponent.stack 385
# opponent.action BET
# opponent.action_value 25
# **************** end ******************
# 31
# ************* state info **************
# nn_current_hand 3
# nn_current_bidding 2
# phase BIDDING
# pot 35
# acting_agent opponent
# parent_state <__main__.GameState object at 0x7faaea8f9370>
# children None
# agent <__main__.PokerPlayer object at 0x7faaea8f9880>
# opponent <__main__.PokerPlayer object at 0x7faaea8f97f0>
# ----- agent -----
# agent.current_hand ['Kc', 'Ts', '4d', 'Jh', 'Jc']
# agent.current_hand_type ['OnePair', 'J', 'h']
# agent.current_hand_strength 36
# agent.stack 380
# agent.action BET10
# agent.action_value 10
# ----- opponent -----
# opponent.current_hand ['5s', '9c', 'Qh', '8h', '3s']
# opponent.current_hand_type ['HighCard', 'Q', 'h']
# opponent.current_hand_strength 24
# opponent.stack 385
# opponent.action BET
# opponent.action_value 25
# **************** end ******************
# 32
# ************* state info **************
# nn_current_hand 3
# nn_current_bidding 1
# phase BIDDING
# pot 10
# acting_agent agent
# parent_state <__main__.GameState object at 0x7faaea8f9160>
# children None
# agent <__main__.PokerPlayer object at 0x7faaea8f9850>
# opponent <__main__.PokerPlayer object at 0x7faaea8f97c0>
# ----- agent -----
# agent.current_hand ['Kc', 'Ts', '4d', 'Jh', 'Jc']
# agent.current_hand_type ['OnePair', 'J', 'h']
# agent.current_hand_strength 36
# agent.stack 380
# agent.action BET10
# agent.action_value 10
# ----- opponent -----
# opponent.current_hand ['5s', '9c', 'Qh', '8h', '3s']
# opponent.current_hand_type ['HighCard', 'Q', 'h']
# opponent.current_hand_strength 24
# opponent.stack 410
# opponent.action CALL
# opponent.action_value 5
# **************** end ******************
# 33
# ************* state info **************
# nn_current_hand 3
# nn_current_bidding 0
# phase SHOWDOWN
# pot 0
# acting_agent opponent
# parent_state <__main__.GameState object at 0x7faaea8f9bb0>
# children None
# agent <__main__.PokerPlayer object at 0x7faaea8f9070>
# opponent <__main__.PokerPlayer object at 0x7faaea8f90a0>
# ---------- showdown ----------
# agent.current_hand ['Ts', 'Ac', 'Ad', 'Qs', '8s']
# ['OnePair', 'A', 'd'] 39
# opponent.current_hand ['8c', 'As', '6c', '4h', 'Kd']
# ['HighCard', 'A', 's'] 26
# showdown_info agent win
# ----- agent -----
# agent.current_hand ['Ts', 'Ac', 'Ad', 'Qs', '8s']
# agent.current_hand_type ['OnePair', 'A', 'd']
# agent.current_hand_strength 39
# agent.stack 390
# agent.action BET10
# agent.action_value 10
# ----- opponent -----
# opponent.current_hand ['8c', 'As', '6c', '4h', 'Kd']
# opponent.current_hand_type ['HighCard', 'A', 's']
# opponent.current_hand_strength 26
# opponent.stack 410
# opponent.action CALL
# opponent.action_value 5
# **************** end ******************
# 34
# ************* state info **************
# nn_current_hand 2
# nn_current_bidding 3
# phase BIDDING
# pot 45
# acting_agent agent
# parent_state <__main__.GameState object at 0x7faaea8f9fd0>
# children None
# agent <__main__.PokerPlayer object at 0x7faaea8f9af0>
# opponent <__main__.PokerPlayer object at 0x7faaea8f9ee0>
# ----- agent -----
# agent.current_hand ['Ts', 'Ac', 'Ad', 'Qs', '8s']
# agent.current_hand_type ['OnePair', 'A', 'd']
# agent.current_hand_strength 39
# agent.stack 340
# agent.action BET10
# agent.action_value 10
# ----- opponent -----
# opponent.current_hand ['8c', 'As', '6c', '4h', 'Kd']
# opponent.current_hand_type ['HighCard', 'A', 's']
# opponent.current_hand_strength 26
# opponent.stack 415
# opponent.action BET
# opponent.action_value 25
# **************** end ******************
# 35
# ************* state info **************
# nn_current_hand 2
# nn_current_bidding 2
# phase BIDDING
# pot 35
# acting_agent opponent
# parent_state <__main__.GameState object at 0x7faaea8f93d0>
# children None
# agent <__main__.PokerPlayer object at 0x7faaea8f9430>
# opponent <__main__.PokerPlayer object at 0x7faaea8f9400>
# ----- agent -----
# agent.current_hand ['Ts', 'Ac', 'Ad', 'Qs', '8s']
# agent.current_hand_type ['OnePair', 'A', 'd']
# agent.current_hand_strength 39
# agent.stack 350
# agent.action BET10
# agent.action_value 10
# ----- opponent -----
# opponent.current_hand ['8c', 'As', '6c', '4h', 'Kd']
# opponent.current_hand_type ['HighCard', 'A', 's']
# opponent.current_hand_strength 26
# opponent.stack 415
# opponent.action BET
# opponent.action_value 25
# **************** end ******************
# 36
# ************* state info **************
# nn_current_hand 2
# nn_current_bidding 1
# phase BIDDING
# pot 10
# acting_agent agent
# parent_state <__main__.GameState object at 0x7faaea8f99a0>
# children None
# agent <__main__.PokerPlayer object at 0x7faaea8f9280>
# opponent <__main__.PokerPlayer object at 0x7faaea8f9c10>
# ----- agent -----
# agent.current_hand ['Ts', 'Ac', 'Ad', 'Qs', '8s']
# agent.current_hand_type ['OnePair', 'A', 'd']
# agent.current_hand_strength 39
# agent.stack 350
# agent.action BET10
# agent.action_value 10
# ----- opponent -----
# opponent.current_hand ['8c', 'As', '6c', '4h', 'Kd']
# opponent.current_hand_type ['HighCard', 'A', 's']
# opponent.current_hand_strength 26
# opponent.stack 440
# opponent.action CALL
# opponent.action_value 5
# **************** end ******************
# 37
# ************* state info **************
# nn_current_hand 2
# nn_current_bidding 0
# phase SHOWDOWN
# pot 0
# acting_agent opponent
# parent_state <__main__.GameState object at 0x7faaea8f91c0>
# children None
# agent <__main__.PokerPlayer object at 0x7faaea8f92e0>
# opponent <__main__.PokerPlayer object at 0x7faaea8f9a30>
# ---------- showdown ----------
# agent.current_hand ['Js', 'Qc', 'Ac', '5c', '7c']
# ['HighCard', 'A', 'c'] 26
# opponent.current_hand ['Kd', '7d', '2s', '5h', '2c']
# ['OnePair', '2', 's'] 27
# showdown_info opponent win
# ----- agent -----
# agent.current_hand ['Js', 'Qc', 'Ac', '5c', '7c']
# agent.current_hand_type ['HighCard', 'A', 'c']
# agent.current_hand_strength 26
# agent.stack 360
# agent.action BET10
# agent.action_value 10
# ----- opponent -----
# opponent.current_hand ['Kd', '7d', '2s', '5h', '2c']
# opponent.current_hand_type ['OnePair', '2', 's']
# opponent.current_hand_strength 27
# opponent.stack 440
# opponent.action CALL
# opponent.action_value 5
# **************** end ******************
# 38
# ************* state info **************
# nn_current_hand 1
# nn_current_bidding 3
# phase BIDDING
# pot 45
# acting_agent agent
# parent_state <__main__.GameState object at 0x7faaeab4a760>
# children None
# agent <__main__.PokerPlayer object at 0x7faaea8f9640>
# opponent <__main__.PokerPlayer object at 0x7faaea8f9b80>
# ----- agent -----
# agent.current_hand ['Js', 'Qc', 'Ac', '5c', '7c']
# agent.current_hand_type ['HighCard', 'A', 'c']
# agent.current_hand_strength 26
# agent.stack 360
# agent.action BET10
# agent.action_value 10
# ----- opponent -----
# opponent.current_hand ['Kd', '7d', '2s', '5h', '2c']
# opponent.current_hand_type ['OnePair', '2', 's']
# opponent.current_hand_strength 27
# opponent.stack 395
# opponent.action BET
# opponent.action_value 25
# **************** end ******************
# 39
# ************* state info **************
# nn_current_hand 1
# nn_current_bidding 2
# phase BIDDING
# pot 35
# acting_agent opponent
# parent_state <__main__.GameState object at 0x7faaeab4a040>
# children None
# agent <__main__.PokerPlayer object at 0x7faaeab4a8b0>
# opponent <__main__.PokerPlayer object at 0x7faaeab4a850>
# ----- agent -----
# agent.current_hand ['Js', 'Qc', 'Ac', '5c', '7c']
# agent.current_hand_type ['HighCard', 'A', 'c']
# agent.current_hand_strength 26
# agent.stack 370
# agent.action BET10
# agent.action_value 10
# ----- opponent -----
# opponent.current_hand ['Kd', '7d', '2s', '5h', '2c']
# opponent.current_hand_type ['OnePair', '2', 's']
# opponent.current_hand_strength 27
# opponent.stack 395
# opponent.action BET
# opponent.action_value 25
# **************** end ******************
# 40
# ************* state info **************
# nn_current_hand 1
# nn_current_bidding 1
# phase BIDDING
# pot 10
# acting_agent agent
# parent_state <__main__.GameState object at 0x7faaeab4a700>
# children None
# agent <__main__.PokerPlayer object at 0x7faaeab4a130>
# opponent <__main__.PokerPlayer object at 0x7faaeab4a430>
# ----- agent -----
# agent.current_hand ['Js', 'Qc', 'Ac', '5c', '7c']
# agent.current_hand_type ['HighCard', 'A', 'c']
# agent.current_hand_strength 26
# agent.stack 370
# agent.action BET10
# agent.action_value 10
# ----- opponent -----
# opponent.current_hand ['Kd', '7d', '2s', '5h', '2c']
# opponent.current_hand_type ['OnePair', '2', 's']
# opponent.current_hand_strength 27
# opponent.stack 420
# opponent.action CALL
# opponent.action_value 5
# **************** end ******************
# 41
# ************* state info **************
# nn_current_hand 1
# nn_current_bidding 0
# phase SHOWDOWN
# pot 0
# acting_agent opponent
# parent_state <__main__.GameState object at 0x7faaeab4a5e0>
# children None
# agent <__main__.PokerPlayer object at 0x7faaeab4aa60>
# opponent <__main__.PokerPlayer object at 0x7faaeab4aa90>
# ---------- showdown ----------
# agent.current_hand ['Tc', '9d', 'Qd', '8h', 'Kh']
# ['HighCard', 'K', 'h'] 25
# opponent.current_hand ['2s', '8s', '4c', '3s', '4h']
# ['OnePair', '4', 'h'] 29
# showdown_info opponent win
# ----- agent -----
# agent.current_hand ['Tc', '9d', 'Qd', '8h', 'Kh']
# agent.current_hand_type ['HighCard', 'K', 'h']
# agent.current_hand_strength 25
# agent.stack 380
# agent.action BET10
# agent.action_value 10
# ----- opponent -----
# opponent.current_hand ['2s', '8s', '4c', '3s', '4h']
# opponent.current_hand_type ['OnePair', '4', 'h']
# opponent.current_hand_strength 29
# opponent.stack 420
# opponent.action CALL
# opponent.action_value 5
# **************** end ******************
# 42
# ************* state info **************
# nn_current_hand 0
# nn_current_bidding 3
# phase BIDDING
# pot 45
# acting_agent agent
# parent_state <__main__.GameState object at 0x7faaeab4a190>
# children None
# agent <__main__.PokerPlayer object at 0x7faaeab4a880>
# opponent <__main__.PokerPlayer object at 0x7faaeab4a940>
# ----- agent -----
# agent.current_hand ['Tc', '9d', 'Qd', '8h', 'Kh']
# agent.current_hand_type ['HighCard', 'K', 'h']
# agent.current_hand_strength 25
# agent.stack 380
# agent.action BET10
# agent.action_value 10
# ----- opponent -----
# opponent.current_hand ['2s', '8s', '4c', '3s', '4h']
# opponent.current_hand_type ['OnePair', '4', 'h']
# opponent.current_hand_strength 29
# opponent.stack 375
# opponent.action BET
# opponent.action_value 25
# **************** end ******************
# 43
# ************* state info **************
# nn_current_hand 0
# nn_current_bidding 2
# phase BIDDING
# pot 35
# acting_agent opponent
# parent_state <__main__.GameState object at 0x7faaeab4a0d0>
# children None
# agent <__main__.PokerPlayer object at 0x7faaeab4a280>
# opponent <__main__.PokerPlayer object at 0x7faaeab4a9d0>
# ----- agent -----
# agent.current_hand ['Tc', '9d', 'Qd', '8h', 'Kh']
# agent.current_hand_type ['HighCard', 'K', 'h']
# agent.current_hand_strength 25
# agent.stack 390
# agent.action BET10
# agent.action_value 10
# ----- opponent -----
# opponent.current_hand ['2s', '8s', '4c', '3s', '4h']
# opponent.current_hand_type ['OnePair', '4', 'h']
# opponent.current_hand_strength 29
# opponent.stack 375
# opponent.action BET
# opponent.action_value 25
# **************** end ******************
# 44
# ************* state info **************
# nn_current_hand 0
# nn_current_bidding 1
# phase BIDDING
# pot 10
# acting_agent agent
# parent_state <__main__.GameState object at 0x7faaeab4a340>
# children None
# agent <__main__.PokerPlayer object at 0x7faaeab4ad60>
# opponent <__main__.PokerPlayer object at 0x7faaeab4abb0>
# ----- agent -----
# agent.current_hand ['Tc', '9d', 'Qd', '8h', 'Kh']
# agent.current_hand_type ['HighCard', 'K', 'h']
# agent.current_hand_strength 25
# agent.stack 390
# agent.action BET10
# agent.action_value 10
# ----- opponent -----
# opponent.current_hand ['2s', '8s', '4c', '3s', '4h']
# opponent.current_hand_type ['OnePair', '4', 'h']
# opponent.current_hand_strength 29
# opponent.stack 400
# opponent.action None
# opponent.action_value None
# **************** end ******************
# 44
# '\nPerform searches\n'
